# %%
# !pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
#empezamos mostrando el dataframe a trabajar sin cambios, desordenado.
import pandas as pd 
dataframe = pd.read_excel('HDI.xlsx')
dataframe
# Out:
#          Back Table 1. Human Development Index and its components   \
# 0         NaN                                                NaN
# 1         NaN                                                NaN
# 2         NaN                                                NaN
# 3         NaN                                                NaN
# 4    HDI rank                                            Country
# ..        ...                                                ...
# 271       NaN                          Column 2: UNDESA (2022a).
# 272       NaN  Column 3: CEDLAS and World Bank (2022), ICF Ma...
# 273       NaN  Column 4: Barro and Lee (2018), ICF Macro Demo...
# 274       NaN  Column 5: IMF (2022), UNDESA (2022b), United N...
# 275       NaN  Column 6: Calculated based on data in columns ...
#
#                          Unnamed: 2  Unnamed: 3                Unnamed: 4  \
# 0                               NaN         NaN                       NaN
# ...

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 276 entries, 0 to 275
# Data columns (total 15 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Back                                                  192 non-null    object
#  1   Table 1. Human Development Index and its components   261 non-null    object
#  2   Unnamed: 2                                            213 non-null    object
#  3   Unnamed: 3                                            0 non-null      float64
#  4   Unnamed: 4                                            214 non-null    object
#  5   Unnamed: 5                                            1 non-null      object
#  6   Unnamed: 6                                            214 non-null    object
#  7   Unnamed: 7                                            101 non-null    object
# ...

# %%
#Observamos qwue hay columnas innecesarias 3,5,7,9,11,13, se eliminan
columnas_inservibles = dataframe.columns[[3,5,7,9,11,13]]
dataframe=dataframe.drop(columns=columnas_inservibles)
dataframe
# Out:
#          Back Table 1. Human Development Index and its components   \
# 0         NaN                                                NaN
# 1         NaN                                                NaN
# 2         NaN                                                NaN
# 3         NaN                                                NaN
# 4    HDI rank                                            Country
# ..        ...                                                ...
# 271       NaN                          Column 2: UNDESA (2022a).
# 272       NaN  Column 3: CEDLAS and World Bank (2022), ICF Ma...
# 273       NaN  Column 4: Barro and Lee (2018), ICF Macro Demo...
# 274       NaN  Column 5: IMF (2022), UNDESA (2022b), United N...
# 275       NaN  Column 6: Calculated based on data in columns ...
#
#                          Unnamed: 2                Unnamed: 4  \
# 0                               NaN                       NaN
# ...

# %%
#Ahora tambien se observa en el excel que hay demasiadas filas, en especial al final
#Estas contienen informacion util pero no esencial, asi que parfa evitar complicaciones serán eliminadas
#Definimos el rango a conservar desde la celda 1 hasta la 230 en vertical, lo demas será eliminado.

dataframe=dataframe.iloc[:230]
dataframe
# Out:
#          Back Table 1. Human Development Index and its components   \
# 0         NaN                                                NaN
# 1         NaN                                                NaN
# 2         NaN                                                NaN
# 3         NaN                                                NaN
# 4    HDI rank                                            Country
# ..        ...                                                ...
# 225       NaN                                                NaN
# 226       NaN  Organisation for Economic Co-operation and Dev...
# 227       NaN                                                NaN
# 228       NaN                                              World
# 229       NaN                                                NaN
#
#                          Unnamed: 2                Unnamed: 4  \
# 0                               NaN                       NaN
# ...

# %%
#eliminamos las primeras filas tambien
dataframe=dataframe.drop(range(0,7))
dataframe
# Out:
#     Back Table 1. Human Development Index and its components  Unnamed: 2  \
# 7      1                                        Switzerland        0.962
# 8      2                                             Norway        0.961
# 9      3                                            Iceland        0.959
# 10     4                             Hong Kong, China (SAR)        0.952
# 11     5                                          Australia        0.951
# ..   ...                                                ...          ...
# 225  NaN                                                NaN          NaN
# 226  NaN  Organisation for Economic Co-operation and Dev...        0.899
# 227  NaN                                                NaN          NaN
# 228  NaN                                              World        0.732
# 229  NaN                                                NaN          NaN
#
#     Unnamed: 4 Unnamed: 6 Unnamed: 8   Unnamed: 10 Unnamed: 12 Unnamed: 14
# ...

# %%
#Ahora podemos renombrar mas facilmente las columnas del dataframe
columnas_nuevas={'Back':'HDI_Rank','Table 1. Human Development Index and its components':'Country','Unnamed: 2':'HDI_Index','Unnamed: 4':'Life_Expectancy',
                'Unnamed: 6':'Expected_schooling_years','Unnamed: 8':'Mean_schooling_years','Unnamed: 10':'GNI_per_capita','Unnamed: 12':'GNIRank_minus_HDIRank',
                'Unnamed: 14':'HDI_Rank_2020'}
dataframe.rename(columns=columnas_nuevas, inplace=True)

# %%
dataframe
# Out:
#     HDI_Rank Table 1. Human Development Index and its components  HDI_Index  \
# 7          1                                        Switzerland       0.962
# 8          2                                             Norway       0.961
# 9          3                                            Iceland       0.959
# 10         4                             Hong Kong, China (SAR)       0.952
# 11         5                                          Australia       0.951
# ..       ...                                                ...         ...
# 225      NaN                                                NaN         NaN
# 226      NaN  Organisation for Economic Co-operation and Dev...       0.899
# 227      NaN                                                NaN         NaN
# 228      NaN                                              World       0.732
# 229      NaN                                                NaN         NaN
#
# ...

# %%
dataframe=dataframe.drop(index=[208,214,216,224,227,229])
dataframe
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 dataframe=dataframe.drop(index=[208,214,216,224,227,229])
#       2 dataframe
#
# File C:\ProgramData\anaconda3\envs\holachauclase\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
# ...
